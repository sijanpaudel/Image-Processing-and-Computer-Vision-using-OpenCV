# %%
import cv2

# %%
img1 = cv2.imread("pic.jpg",-1)

# %%
cv2.imshow("Image Window",img1)
cv2.waitKey(30000)
cv2.destroyAllWindows()

# %%
img1 = cv2.resize(img1,(1920,1080))
cv2.imshow("Original",img1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
import cv2
img1 = cv2.imread("pic.jpg",0)
img1 = cv2.resize(img1,(560,700))
cv2.imwrite("img.png",img1)
# Out:
# True

# %%
import cv2
img1 = cv2.imread("pic.jpg",0)
img1 = cv2.resize(img1,(560,700))
cv2.imshow("Window",img1)
while True:
    k = cv2.waitKey(0)
    if k == ord('s'):
        cv2.imwrite("Saved.png",img1)
    else:
        cv2.destroyAllWindows()

# %%
import cv2
img1 = cv2.imread("pic.jpg",0)
img1 = cv2.resize(img1,(560,700))
img1 = cv2.flip(img1,-1)
cv2.imshow("Windows",img1)
while True:
    k = cv2.waitKey(0)
    if k == ord('s'):
        cv2.imwrite("hehe.jpg",img1)
    else:
        cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
cap = cv2.VideoCapture("video.mp4")
while True:
    ret, frame = cap.read()
    cv2.imshow("Windows",frame)
    cv2.waitKey(25)
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
cap = cv2.VideoCapture("video.mp4")
while True:
    ret, frame = cap.read()
    frame = cv2.resize(frame,(700,450))
    gray = cv2.cvtColor(frame,6)
    cv2.imshow("Windows",gray)
    k = cv2.waitKey(25)
    if k == ord("q") & 0xFF:
        break
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
cap = cv2.VideoCapture("video.mp4")
while True:
    ret,frame = cap.read()
    frame = cv2.resize(frame,(700,450))
    gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    cv2.imshow("Window",gray)
    k = cv2.waitKey(25)
    if k == ord("q") & 0xFF:
        break
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret,frame = cap.read()
    frame = cv2.resize(frame, (700,450))
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    if ret == True:
        cv2.imshow("Original",frame)
        if cv2.waitKey(1) == ord("q") & 0xFF:
            break
cap.release()
cv2.destroyAllWindows()

# %%
x = {"name":"Sijan","age":22}
def test(name,age):
    print(name,age)
def test1(**kwargs):
    print(kwargs)
test(**x)
test1(name="Sijan",age=22)
print(x)
# Out:
# Sijan 22
# {'name': 'Sijan', 'age': 22}
# {'name': 'Sijan', 'age': 22}

# %%
list1 = [1,2,3]
list2 = [4,5]
list3 = [6,7,8]
x = (*list1,*list2)
x
# Out:
# (1, 2, 3, 4, 5)

# %%
my_list = [1,2,3,4,5,6]
x,*y,z = my_list
y
# Out:
# [2, 3, 4, 5]

# %%
import cv2
camera = "http://192.168.1.101:8080/video"
cap = cv2.VideoCapture(camera)
fourcc = cv2.VideoWriter_fourcc(*"XVID")
output = cv2.VideoWriter("output.avi",fourcc,20.0,(640,480))
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    cv2.imshow("Windows",frame)
    output.write(frame)
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break
cap.release()
output.release()
cv2.destroyAllWindows()
# Out:
# [mjpeg @ 0x55aa751494c0] overread 8
# [mjpeg @ 0x55aa751494c0] overread 8
# [mjpeg @ 0x55aa751494c0] overread 8

# %%
import cv2

# Open the default camera (camera index 0)
cap = cv2.VideoCapture(0)

# Define the codec and create a VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'XVID')
output = cv2.VideoWriter('output.avi', fourcc, 20.0, (640, 480))

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()

    if not ret:
        break

    # Write the frame to the output video
    output.write(frame)

    # Display the frame
    cv2.imshow('Frame', frame)

    # Press 'q' to exit the loop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the VideoCapture and VideoWriter objects
cap.release()
output.release()

# Close all OpenCV windows
cv2.destroyAllWindows()

# %%
import cv2
camera = "https://www.youtube.com/watch?v=wL8DVHuWI7Y&ab_channel=Narvent"
cap = cv2.VideoCapture(0)
fourcc = cv2.VideoWriter_fourcc(*"XVID")
output = cv2.VideoWriter("hehe.avi",fourcc,20.0,(640,480))
while cap.isOpened():
    ret,frame = cap.read()
    frame = cv2.resize(frame,(640,480))
    cv2.imshow("Original",frame)
    output.write(frame)
    if cv2.waitKey(1)==ord("q"):
        break
cap.release()
cv2.destroyAllWindows()

# %%
# !pip install pafy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# !youtube-dl --update
# Out:
# Usage: youtube-dl [OPTIONS] URL [URL...]
#
# youtube-dl: error: youtube-dl's self-update mechanism is disabled on Debian.
# Please update youtube-dl using apt(8).
# See https://packages.debian.org/sid/youtube-dl for the latest packaged version.

# %%
import pyautogui
pyautogui.moveTo(100,100)
pyautogui.click()

# %%
import tkinter as tk

# Create a window
window = tk.Tk()

# Create a label
label = tk.Label(window, text="Hello, tkinter!")

# Add the label to the window
label.pack()

# Start the GUI event loop
window.mainloop()

# %%
#Screen Recorder
import cv2 
import numpy as np
import pyautogui as p

#Create resolution
rs = p.size()

# filename in which we store recording
fn = "rec.avi"
#fix the frame rate
fps = 20.0

fourcc = cv2.VideoWriter_fourcc(*"XVID")
output = cv2.VideoWriter(fn, fourcc, fps, rs)

#create recording module
cv2.namedWindow("Live_Recording",cv2.WINDOW_NORMAL)
cv2.resizeWindow("Live_Recording",(600,400))

while True:
    img = p.screenshot()
    f = np.array(img)
    f = cv2.cvtColor(f,cv2.COLOR_BGR2RGB)
    output.write(f)
    cv2.imshow("Live_Recording",f)
    if cv2.waitKey(1) == ord('q'):
        break
output.release()
cv2.destroyAllWindows()

# %%
import pyautogui
import cv2
import matplotlib.pyplot as plt
import numpy as np
screenshot = pyautogui.screenshot()
arr = np.array(screenshot)
#arr = cv2.cvtColor(arr, cv2.COLOR_BGR2RGB)
# filename in which we store recording
fn = "rec.avi"
#fix the frame rate
fps = 20.0
rs = pyautogui.size()
fourcc = cv2.VideoWriter_fourcc(*"XVID")
output = cv2.VideoWriter(fn, fourcc, fps, (640,480))

output.write(arr)

# %%
#Break images into multiple images and store in a folder
import cv2

videocap = cv2.VideoCapture("video.mp4")

count = 0
while True:
    ret,frame = videocap.read()
    if ret == False:
        break
    cv2.imwrite("imgN%d.jpg"%count,frame)
    videocap.set(cv2.CAP_PROP_POS_MSEC,(count*1000))
    cv2.imshow("res",frame)

    count+=1
    if cv2.waitKey(1) == ord("q"):
        break
videocap.release()
cv2.destroyAllWindows()

# %%
#Drawing functions in opencv

import numpy as np
import cv2

#img = cv2.imread("pic.jpg")
#img = cv2.resize(img,(700,700))
img = np.zeros([512,512,3]) #For black screen

#Here line accept 5 parameters (img, starting, ending, color, thickness)
img = cv2.line(img,(0,0),(200,200),(154,92,424),8)  #Color format BGR

#arrowed line also accepts 5 parameters (img, starting, ending, color, thickness)
img = cv2.arrowedLine(img,(0,125),(255,255),(255,0,125),10)

#Rectangle - accept parameter (img, start_co, end_co, color, thickness)
img = cv2.rectangle(img, (384,10), (510,128),(128,0,255),-1)

#Circle - accept (img, start_co, radius, color, thickness)
img = cv2.circle(img, (447,125), 63, (214,255,0), 5)

font = cv2.FONT_HERSHEY_SIMPLEX#cv2.FONT_ITALIC
#puttext - accept(img, text, start_co, font, font_size, color, thickness, linetype)
img = cv2.putText(img, "Reboot", (20,500), font, 2, (0,125,255), 5, cv2.LINE_AA )

img = cv2.ellipse(img, (400,600), (100,50), 0, 0, 260, (125,0,255), 8, cv2.LINE_AA )

cv2.imshow("res",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#Draw Date Time and figures on video
import cv2
import datetime

cap = cv2.VideoCapture("video.mp4")

width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)
height = cap.get(4)
font = cv2.FONT_HERSHEY_COMPLEX

while cap.isOpened():
    ret, frames = cap.read()
    if ret == True:
        text = "Height: " + str(height) + " Width: " + str(width)
        img = cv2.putText(frames, text, (10,30), font, 1, (0,155,255), 1, cv2.LINE_AA)
        date_data = "Date" + str(datetime.datetime.now())
        img = cv2.putText(img, date_data, (20,60), font, 1, (100,255,255), 1, cv2.LINE_AA)
        cv2.imshow("Video",img)
        if cv2.waitKey(20) == ord("q"):
            break
    else: 
        break
cap.release()
cv2.destroyAllWindows()

# %%
import datetime

datetime.datetime.now()
# Out:
# datetime.datetime(2023, 9, 14, 9, 54, 43, 24)

# %%
# Mouse Callback Functions
import cv2
import numpy as np

def draw(event, x, y, flags, param):
    if event == cv2.EVENT_LBUTTONDBLCLK:
        cv2.circle(img, (x,y), 100, (125,0,255), 5)
    if event == cv2.EVENT_RBUTTONDBLCLK:
        cv2.rectangle(img, (x,y), (x+100, y+75), (125,125,255),2)

cv2.namedWindow("res")

img = np.zeros([512,512,3])
cv2.setMouseCallback("res",draw)

while True:
    cv2.imshow("res",img)
    if cv2.waitKey(1) & 0xFF == 27: #escape key
        break

cv2.destroyAllWindows()

# %%
#Create a function which helps to find coordinate of any pixel and its color
import cv2
import numpy as np 

def mouse_event(event,x,y,flag,param):
    font = cv2.FONT_HERSHEY_COMPLEX
    if event == cv2.EVENT_LBUTTONDOWN:
        print(x," , ",y)
        cord = ". " + str(x)+", " + str(y)
        cv2.putText(img, cord, (x,y), font, 1,(155,125,100),2,cv2.LINE_AA)
        #cv2.imshow("image", img)

    if event == cv2.EVENT_RBUTTONDOWN:
        b = img[y,x,0]
        g = img[y,x,1]
        r = img[y,x,2]
        color_bgr = ". "+str(b)+", "+str(g)+", " +str(r)
        cv2.putText(img, color_bgr, (x,y), font, 1, (152,255,130),2)
        #cv2.imshow("image",img)

cv2.namedWindow("image")

#img = np.zeros([512,512,3])
img = cv2.imread("pic.jpg")
cv2.setMouseCallback("image",mouse_event)

while True:
    cv2.imshow("image",img)
    if cv2.waitKey(1) == ord("q"):
        break

cv2.destroyAllWindows()
# Out:
# 946  ,  311
# 366  ,  231
# 201  ,  226
# 83  ,  385
# 664  ,  419
# 620  ,  402
# 326  ,  458

# %%
#Building color picker using Trackbars

import cv2
import numpy as np

def cross(x):
    pass

#blank
img = np.zeros((300,512,3),np.uint8)
cv2.namedWindow("Color Picker")

#Create Switch
s1 = "0:OFF\n1:ON"
cv2.createTrackbar(s1,"Color Picker",0,1,cross)

#creating for rgb

#Creating Trackbars for Adjusting Colors
cv2.createTrackbar("R","Color Picker",0,255,cross)
cv2.createTrackbar("G","Color Picker",0,255,cross)
cv2.createTrackbar("B","Color Picker",0,255,cross)

while True:
    cv2.imshow("Color Picker",img)
    if cv2.waitKey(1) == ord("q"):
        break

    # Now get trackbar Position
    s = cv2.getTrackbarPos(s1,"Color Picker")
    r = cv2.getTrackbarPos("R","Color Picker")
    g = cv2.getTrackbarPos("G","Color Picker")
    b = cv2.getTrackbarPos("B","Color Picker")
    
    if s == 0:
        img[:] = [0]
    else:
        img[:] = [b, g, r]

cv2.destroyAllWindows()

# %%
 # Image Operations with pixels and coordinates
import cv2
import numpy as np

#Read an image
img = cv2.imread("pic.jpg")

print("shape=",img.shape)
print("no. of pixels=",img.size)
print("datatype=",img.dtype)
print("Image type = ",type(img))

b,g,r = cv2.split(img)
#cv2.imshow("b",b)

#Now if you want to mix the channels then use merge
mr1 = cv2.merge((b,g,r))
cv2.imshow("merged",mr1)

#cv2.imshow("res",img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# shape= (720, 1280, 3)
# no. of pixels= 2764800
# datatype= uint8
# Image type =  <class 'numpy.ndarray'>

# %%
#Working on pixel color values
import cv2
import numpy as np

img = cv2.imread("pic.jpg")
cv2.imshow("res",img)

#Access a pixel by its row and column coordinate
px = img[520,580]
print(px)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# [27 30 35]

# %%
 #Region of Interest (ROI)
import cv2
import numpy as np

#read 
img = cv2.imread("pic.jpg")

#ROI
#(530,260)
#(750,300)
roi = img[260:300, 530:750]
#cv2.imshow("roi",roi)
img[260:300, 200:420] = roi



cv2.imshow("img",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#Creating Image Borders
import cv2
import numpy as np

img1 = cv2.imread("pic.jpg")

#specifying border size
top = bottom = left = right = 10

#creating image border
brdr = cv2.copyMakeBorder(img1, top, bottom, left, right, cv2.BORDER_CONSTANT, value=(30,0,0) )

cv2.imshow("res", brdr)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#Image blending with open CV
#Here we use two important functions cv2.add(), cv2.addWeight()
#Blending means addition of two images
#if we want to blend images then both have same size

import cv2
import numpy as np

img1 = cv2.imread("pic.jpg")
img1 = cv2.resize(img1, (500,500))
img2 = cv2.imread("pic1.jpg")

#add = img2 + img1
#add = cv2.add(img1, img2)
addweight = cv2.addWeighted(img1, 0.7,img2, 0.3, 0 )

#cv2.imshow("Add", add)
cv2.imshow("Add weighted",addweight)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#Project on Image Blending using Trackbars
import cv2
import numpy as np

image1 = cv2.imread("pic.jpg")
image1 = cv2.resize(image1, (500,500))
image2 = cv2.imread("pic1.jpg")

def cross(x):
    pass

cv2.namedWindow("Project")

img_black = np.zeros((500,500,3), np.uint8)
s = "0:OFF\n1:ON"
cv2.createTrackbar(s,"Project",0,1,cross)
cv2.createTrackbar("alpha","Project",0,10,cross)
cv2.createTrackbar("gamma","Project",0,10,cross)


while True:
    s1 = cv2.getTrackbarPos(s,"Project")
    alpha = cv2.getTrackbarPos("alpha","Project")
    gamma = cv2.getTrackbarPos("gamma","Project")
    if s1 == 0:
        cv2.imshow("Project",img_black)
    else:
        addwt = cv2.addWeighted(image1,alpha*0.1,image2,1-alpha*0.1,gamma)
        addwt = cv2.putText(addwt,str(alpha),(20,40),cv2.FONT_HERSHEY_COMPLEX,1,(0,0,0),2)
        cv2.imshow("Project",addwt)
    if cv2.waitKey(1) == ord("q"):
        break

cv2.destroyAllWindows()

# %%
#Bitwise Operations includes AND, OR, NOT, XOR
#It is most important and used for various purposes like masking and find roi which is in complex shape

import cv2
import numpy as np

img1 = np.zeros((250,500,3),np.uint8)
img1 = cv2.rectangle(img1,(150,100),(200,250),(255,255,255),-1)

img2 = np.zeros((250,500,3),np.uint8)
img2 = cv2.rectangle(img2,(10,10),(170,190),(255,255,255),-1)

#cv2.imshow("img1",img1)
#cv2.imshow("img2",img2)

bitAnd = cv2.bitwise_and(img2,img1)
#cv2.imshow("and",bitAnd)

bitOr = cv2.bitwise_or(img1,img2)
#cv2.imshow("or",bitOr)

bitNot = cv2.bitwise_not(img1)
#cv2.imshow("Not",bitNot)

bitXor = cv2.bitwise_xor(img1,img2)
cv2.imshow("XOR",bitXor)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#Detect Color in a Image

import cv2
import numpy as np

frame = cv2.imread("color_balls.jpg")

hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

while True:
    #66, 135, 245 42, 84, 150 #252, 92, 5 #179, 65, 4
    u_v = np.array([130,235,225])
    l_v = np.array([110,50,50])
    
    #Creating Mask
    mask = cv2.inRange(hsv, l_v, u_v)
    cv2.imshow("Mask", mask)

    # filter mask with image
    res = cv2.bitwise_and(frame, frame, mask = mask)
    cv2.imshow("Res",res)

    if cv2.waitKey(1) == ord("q"):
        break

cv2.destroyAllWindows()

# %%
#Color detection using trackbars

import cv2
import numpy as np

frame = cv2.imread("color_balls.jpg")
frame = cv2.resize(frame, (600,400))

def nothing(x):
    pass

cv2.namedWindow("Color Adjustments")

cv2.createTrackbar("Lower_H", "Color Adjustments", 0, 255, nothing)
cv2.createTrackbar("Lower_S", "Color Adjustments", 0, 255, nothing)
cv2.createTrackbar("Lower_V", "Color Adjustments", 0, 255, nothing)

cv2.createTrackbar("Upper_H", "Color Adjustments", 255, 255, nothing)
cv2.createTrackbar("Upper_S", "Color Adjustments", 255, 255, nothing)
cv2.createTrackbar("Upper_V", "Color Adjustments", 255, 255, nothing)

while True:
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

    l_h = cv2.getTrackbarPos("Lower_H", "Color Adjustments")
    l_s = cv2.getTrackbarPos("Lower_S", "Color Adjustments")
    l_v = cv2.getTrackbarPos("Lower_V", "Color Adjustments")

    u_h = cv2.getTrackbarPos("Upper_H", "Color Adjustments")
    u_s = cv2.getTrackbarPos("Upper_S", "Color Adjustments")
    u_v = cv2.getTrackbarPos("Upper_V", "Color Adjustments")

    lower_boud = np.array([l_h, l_s, l_v])
    upper_boud = np.array([u_h, u_s, u_v])

    mask = cv2.inRange(hsv, lower_boud, upper_boud)

    res = cv2.bitwise_and(frame, frame ,mask=mask)

    cv2.imshow("Mask",mask)
    cv2.imshow("Result", res)

    if cv2.waitKey(1) == ord("q"):
        break

cv2.destroyAllWindows()

# %%
#Detecting Color using webcam and trackbar

import cv2
import numpy as np

cap = cv2.VideoCapture(0)

def nothing(x):
    pass

cv2.namedWindow("Color Adjustments")

cv2.createTrackbar("Lower_H", "Color Adjustments", 0, 255, nothing)
cv2.createTrackbar("Lower_S", "Color Adjustments", 0, 255, nothing)
cv2.createTrackbar("Lower_V", "Color Adjustments", 0, 255, nothing)

cv2.createTrackbar("Upper_H", "Color Adjustments", 255, 255, nothing)
cv2.createTrackbar("Upper_S", "Color Adjustments", 255, 255, nothing)
cv2.createTrackbar("Upper_V", "Color Adjustments", 255, 255, nothing)

while True:
    ret, frame = cap.read()
    frame = cv2.resize(frame, (400,400))
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

    l_h = cv2.getTrackbarPos("Lower_H", "Color Adjustments")
    l_s = cv2.getTrackbarPos("Lower_S", "Color Adjustments")
    l_v = cv2.getTrackbarPos("Lower_V", "Color Adjustments")

    u_h = cv2.getTrackbarPos("Upper_H", "Color Adjustments")
    u_s = cv2.getTrackbarPos("Upper_S", "Color Adjustments")
    u_v = cv2.getTrackbarPos("Upper_V", "Color Adjustments")

    lower_boud = np.array([l_h, l_s, l_v])
    upper_boud = np.array([u_h, u_s, u_v])

    #Creating mask
    mask = cv2.inRange(hsv,lower_boud, upper_boud)

    #Filtering image with mask
    res = cv2.bitwise_and(frame, frame, mask=mask)

    cv2.imshow("frame",frame)
    cv2.imshow("mask",mask)
    cv2.imshow("Detect",res)

    if cv2.waitKey(1) == ord("q"):
        break

cv2.destroyAllWindows()

# %%
#Simple Thresholding

import numpy as np
import cv2

img = cv2.imread("black_white.png",0)
img = cv2.resize(img, (300,300))

cv2.imshow("Original",img)

_, th1 = cv2.threshold(img, 50, 255, cv2.THRESH_BINARY)
_, th2 = cv2.threshold(img, 50, 255, cv2.THRESH_BINARY_INV)
_, th3 = cv2.threshold(img, 127, 255, cv2.THRESH_TRUNC)
_, th4 = cv2.threshold(img, 127, 255, cv2.THRESH_TOZERO)
_, th5 = cv2.threshold(img, 127, 255, cv2.THRESH_TOZERO_INV)

cv2.imshow("1 - THRESH_BINARY",th1)
cv2.imshow("2 - THRESH_BINARY_INV",th2)
cv2.imshow("3 - THRESH_TRUNC", th3)
cv2.imshow("4 - THRESH_TOZERO", th4)
cv2.imshow("5 - THRESH_TOZERO_INV", th5)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#Adaptive Thresholding
import cv2

img = cv2.imread("page.jpg",0)
img = cv2.resize(img, (400,400))

th2 = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY,11,2)
th3 = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY,11,2)


cv2.imshow("Image",img)
cv2.imshow("Adaptive-1",th2)
cv2.imshow("Adaptive-2",th3)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#Extracting object from the image and place on another image
#Random figure ROI or background subtraction

import cv2
import numpy as np

#Load two images
img1 = cv2.imread("hero1.jpg")
img2 = cv2.imread("strom_breaker.jpeg")

img1 = cv2.resize(img1, (1024,650))
img2 = cv2.resize(img2, (600,650))

r,c,ch = img2.shape
print(r,c,ch)

#ROI
roi = img1[0:r,0:c]

#Now creating mask for img2
img_gry = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)

#Create mask using threshold
_,mask = cv2.threshold(img_gry,50,255,cv2.THRESH_BINARY)

#Remove bg
mask_inv = cv2.bitwise_not(mask)

#put mask into roi
img1_bg = cv2.bitwise_and(roi,roi,mask= mask_inv)

#Take only region of figure from original image
img2_fg = cv2.bitwise_and(img2, img2, mask=mask)

#Put object in ROI and modify the main image
res = cv2.add(img1_bg, img2_fg)

final = img1
final[0:r,0:c] = res

cv2.imshow("ROI",roi)
cv2.imshow("Step-1 gry",img_gry)
cv2.imshow("Step-2 mask",mask)
cv2.imshow("Step-3 Mask_inv",mask_inv)
cv2.imshow("Step-4 Mask bg",img1_bg)
cv2.imshow("Step-5 Mask foreground",img2_fg)
cv2.imshow("Step-6 Res",res)
cv2.imshow("final",img1)


cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 650 600 3

# %%
#Morphological Transformations
#Morphological transformations are some simple operations based on image shape.
#It is normally performed on binary images
#It needs two inputs, 1) Original Image, 2) Structuring Element (Kernal).
#Two basic morphological transformations are: 1) Erosion, 2) Dilation

import cv2
import numpy as np

#Erosion
#It erodes away the boundaries of foreground object

#Kernal slides through all the image and all the pixel

img = cv2.imread("col_balls.jpg",0)

_, mask = cv2.threshold(img, 230, 255, cv2.THRESH_BINARY_INV)
kernal = np.ones((5,5),np.uint8) # 5*5 kernal with full of ones
e = cv2.erode(mask,kernal)

#Dilation
#It is just opposite of erosion
#It increases the white region in the image or size of foreground object in
#Normally in cases like noise removal, erosion is followed by dilation
#Because erosion removes white noises, but it also shrinks our object.

kernal = np.ones((3,3),np.uint8)
d = cv2.dilate(mask, kernal)

#using matplotlib to plot it
import matplotlib.pyplot as plt
titles = ["img", "mask", "erosion", "dilation"]
images = [img,mask,e,d]
for i in range(4):
    plt.subplot(2,2,i+1)
    plt.imshow(images[i],"gray")
    plt.title(titles[i])
    plt.xticks([])
    plt.yticks([])

cv2.imshow("img",img)
cv2.imshow("mask",mask)
cv2.imshow("ker",kernal)
cv2.imshow("erosion",e)
cv2.imshow("dilation",d)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#Two more basic morphological transformations
# 1) Opening, 2) Closing

import cv2
import numpy as np
import matplotlib.pyplot as plt
#Opening 
#Opening is just another name of erosion followed by dilation.
#means first erosion takes place then dilation

img = cv2.imread("col_balls.jpg",0)
_,mask = cv2.threshold(img,230,255,cv2.THRESH_BINARY_INV)
kernal = np.ones((3,3), np.uint8)
o = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernal)

#Closing
#It is opposite of opening
#Closing is just another name of dilation followed by erosion
#means first dilation takes place then erosion

c = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernal)

title = ["img","mask","opening","closing"]
images = [img, mask, o, c]
for i in range(4):
    plt.subplot(2,2,i+1)
    plt.imshow(images[i], "gray")
    plt.title(title[i])
    plt.xticks([])
    plt.yticks([])

# %%
#Image Smoothing or bluring is most common used operation in Image Processing
#It is used to remove the noise from the images
#There are so many filter which is use for smoothing the image
#There are Low Pass Filter which is used to remove Noise from the images
#There are High Pass Filter which is used to detect and finding edges in an image
#Various Flters -- homogeneous, blur(averaging), gaussian, median, bilateral

import cv2
import numpy as np

img = cv2.imread("noisy.jpg")
img = cv2.resize(img, (400,400))
cv2.imshow("Original",img)

kernal = np.ones((5,5),np.float32)/25

#Filter Number- 1
#This filter work like each output pixel is the mean of its kernal neighbour
#it is aka homogeneous filter in this all pixel contribute with equal weight
#kernal is a small shape or matrix which we apply on image
#in this filter kernal is [(1/kernal(h,w))*kernal]
h_filter = cv2.filter2D(img, -1, kernal)
cv2.imshow("homogeneous",h_filter)  #- -1 is desired depth

#Filter Number - 2
#Blur method or averaging
#Takes the average of all the pixels under the kernal area
#replaces the central element with this average
blur = cv2.blur(img, (8,8)) #Here we have image and kernal as parameter
cv2.imshow("blur",blur)

#Filter Number - 3
#Gaussian Filter - here it is using different weight kernal, in row as well as column
#means side values are small than centre. It manage distance b/w value of pixel
gau = cv2.GaussianBlur(img, (5,5), 0)
cv2.imshow("gau blur",gau)

#Filter Number - 4
#Median Filter - computes the median of all the pixels under the 
#kernal window and the central pixel is replaced with this median value
#This is highly effective in removing salt-and-pepper noise.
#here kernal size must be odd except one
med = cv2.medianBlur(img,5)
cv2.imshow("median filter",med)

#Filter Number - 5
#Bilateral Filter --- is highly effective at noise removal while preserving edges
#It works like gaussian filter but more focus on edges
#It is slow as compare with other filters
#argument (img, neighbour_pixel_diameter, sigma_color, sigma_space)
bi_f = cv2.bilateralFilter(img, 9, 75, 75)
cv2.imshow("bi_f",bi_f)

#Now plot all the images in graph
titles = ["img","homogeneous","blur","gaussian blur","median filter","bi_f"]
images = [img,h_filter, blur, gau, med, bi_f]
import matplotlib.pyplot as plt
for i in range(6):
    plt.subplot(2,3,i+1)
    plt.title(titles[i])
    plt.imshow(images[i])
    plt.xticks([])
    plt.yticks([])
                           
cv2.waitKey(0)



cv2.destroyAllWindows()

# %%
#Image Gradient
#It is an directional change in the color or intensity in an image.
#It is most important part to find information from image.
#Like finding edges within the images.
#There are various methods to find image gradient.
#These are Laplacian Derivatives, SobelX and SobelY.
#All these functions have different mathematical apporach to get result.
#All load image in the gray scale

import cv2
import numpy as np

#Load image into gray scale
img = cv2.imread("building.jpg")
img = cv2.resize(img,(600,500))
img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

#Laplacian derivatives -- it calculate laplace derivative
#parameter (img, data_type for -ve val)
lap = cv2.Laplacian(img_gray, cv2.CV_64F,ksize=3)
lap = np.uint8(np.absolute(lap))

#Sobel operation- 
#is a joint Gaussian smoothing plus differentiation operation,
#so, it is more resistant to noise.
#This is use for x and y both
#parameter (img, type for -ve val, x=1, y=0, ksize)
#Sobel X focus on vertical lines
#Sobel Y focus on horizontal lines

sobelX = cv2.Sobel(img_gray,cv2.CV_64F,1,0,ksize=3)
sobelY = cv2.Sobel(img_gray,cv2.CV_64F,0,1,ksize=3)

sobelX = np.uint8(np.absolute(sobelX))
sobelY = np.uint8(np.absolute(sobelY))

#Finally combine sobelX and sobelY together
sobelCombine = cv2.bitwise_or(sobelX,sobelY)

cv2.imshow("Original",img)
cv2.imshow("Gray",img_gray)
cv2.imshow("Laplacian",lap)
cv2.imshow("SobelX",sobelX)
cv2.imshow("SobelY",sobelY)
cv2.imshow("Sobel Combine",sobelCombine)
cv2.waitKey(0)
cv2.destroyAllWindows()

#plot in graph 
titles = ["Original","Gray","Laplacian","SobelX","SobelY","Sobel Combine"]
images = [img,img_gray,lap,sobelX,sobelY,sobelCombine]

import matplotlib.pyplot as plt
for i in range(6):
    plt.subplot(2,3,i+1)
    plt.title(titles[i])
    plt.imshow(images[i],"gray")
    plt.xticks([])
    plt.yticks([])

# %%
#Canny Edge detection using openCV
#Canny Edge detection is a popular edge detection approach.
#It use multi-stage algorithm to detect edges.
#This approach contains 5 steps:
#1) Noise Reduction 2) Gradient Calculation 3) Non-Maximum Supression
#4) Double Threshold 5) Edge Tracking by hysteresis
import cv2
import numpy as np

#Load image into gray scale
img = cv2.imread("building.jpg")
img = cv2.resize(img,(600,600))
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

#Canny(img, thresh1, thresh2)
canny = cv2.Canny(img_gray,50,150)

cv2.imshow("Original",img)
cv2.imshow("Gray",img_gray)
cv2.imshow("Canny",canny)

cv2.waitKey(0)
cv2.destroyAllWindows()

#Plot in graph
titles = ["Original","Gray","Canny"]
images = [img, img_gray, canny]
import matplotlib.pyplot as plt
for i in range(3):
    plt.subplot(1,3,i+1)
    plt.imshow(images[i],"gray")
    plt.title(titles[i])
    plt.xticks([])
    plt.yticks([])

# %%
#Canny Edge Detection using trackbars
import cv2

img = cv2.imread("building.jpg",0)
img = cv2.resize(img, (600,600))

def nothing(x):
    pass

cv2.namedWindow("Canny")
cv2.createTrackbar("lower threshold", "Canny", 0, 255, nothing)
cv2.createTrackbar("upper threshold", "Canny", 50, 255, nothing)

while True:
    l_th = cv2.getTrackbarPos("lower threshold","Canny")
    u_th = cv2.getTrackbarPos("upper threshold", "Canny")
    canny = cv2.Canny(img,l_th,u_th)
    cv2.imshow("Canny",canny)
    if cv2.waitKey(1) == ord("q"):
        break

cv2.destroyAllWindows()

# %%
#Image Pyramid in OpenCV
"""
We use image Pyramid because sometimes we work on same image but different resolution e.g. searching face, eye in an image
and it vary image to image so in this case we create a set of images with different resolution which is called pyramid.
We also use these pyramids to blend the images.
"""
#there are two types of image pyramids:
#1) Gaussian Pyramid  2) Laplacian Pyramid

import cv2
import numpy as np

img = cv2.imread("avengers.jpg")
img = cv2.resize(img,(700,700))

"""#Gaussian Pyramid have two functions: 1) cv2.pyrUp   2) cv2.pyrDown
pd1 = cv2.pyrDown(img)
pd2 = cv2.pyrDown(pd1)

pu1 = cv2.pyrUp(pd2)

cv2.imshow("Original",img)
cv2.imshow("pd1",pd1)
cv2.imshow("pd2",pd2)
cv2.imshow("pu1",pu1)"""

img1 = img.copy()
data = [img1]
for i in range(4):
    cv2.imshow("res"+str(i),img1)
    img1 = cv2.pyrDown(img1)
    data.append(img1)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#Contours
#contours can be explained simply as a curve joining all the continuous points
#(along the boundary), having same color or intensity

#the contours are a useful tool for shape analysis and object detection

#For better accuracy, use binary images and also apply edge detection before finding contours

#findContour function manipuate original image so copy it before proceeding.
#findContour fuction is like finding white object from black background.
#so you must turn image in white and background is black.

#We have to find and draw contours as per the requirement.

import cv2
import numpy as np

img = cv2.imread("logo.jpg")
img1 = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(img1,27,255,cv2.THRESH_BINARY)

#findcontours(img, contours_retrival_mode, method)
conts, hier = cv2.findContours(thresh, cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)

#print(conts,len(conts))

#drawcontour(img, conts, id_of_contour, color, thickness)
#Draw the contours
img = cv2.drawContours(img, conts, -1, (25,100,15), 4)

#output
cv2.imshow("Original",img)
cv2.imshow("Gray",img1)
cv2.imshow("Thresh",thresh)

cv2.waitKey(0)
cv2.destroyAllWindows()

import matplotlib.pyplot as plt
plt.title("Contours")
plt.imshow(img[:,:,::-1])
plt.axis("off")
# Out:
# (-0.5, 221.5, 261.5, -0.5)

# %%
#Contours and its function
#Moment
#Approximation
#Convex Hull

import cv2
import numpy as np

img = cv2.imread("shapes.png")
img = cv2.resize(img, (600,700))
img1 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(img1, 170, 255, cv2.THRESH_BINARY_INV)

cnts, hier = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

#img = cv2.drawContours(img, cnts, -1, (100,20,100), 2)
#Loop over the contours
for c in cnts:
    M = cv2.moments(c)
    cX = int(M["m10"]/M["m00"])
    cY = int(M["m01"]/M["m00"])
    #Draw the contour and the center of the shape on the image
    cv2.drawContours(img,[c],-1,(0,255,0),2)
    cv2.circle(img,(cX,cY),7,(255,255,255),-1)
    cv2.putText(img, "center",(cX-20,cY-20),cv2.FONT_HERSHEY_SIMPLEX,0.5,(255,255,255),1)

cv2.imshow("original", img)
cv2.imshow("gray",img1)
cv2.imshow("Thresh",thresh)

cv2.waitKey(0)
cv2.destroyAllWindows()

import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.imshow(img[:,:,::-1])
plt.title("Contours")
plt.axis("off")
# Out:
# (-0.5, 599.5, 699.5, -0.5)

# %%
#Contour Area, Approximation and Convex Hull
import cv2
import numpy as np

img = cv2.imread("shapes.png")
img = cv2.resize(img,(600,700))
img1 = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

ret,thresh = cv2.threshold(img1,170,255,cv2.THRESH_BINARY_INV)

cnts,hier = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

area1 = []
for c in cnts:
    M = cv2.moments(c)
    cX = int(M["m10"]/M["m00"])
    cY = int(M["m01"]/M["m00"])

    #find the area of contour 
    area = cv2.contourArea(c)
    area1.append(area)

    #Contour Approx - it is used to approx shape with less number of vertices
    epsilon = 0.01 * cv2.arcLength(c, True)
    data = cv2.approxPolyDP(c, epsilon, True)

    #Convex Hull is used to provide proper contours convexity
    hull = cv2.convexHull(data)
    x,y,w,h = cv2.boundingRect(hull)
    img = cv2.rectangle(img, (x,y), (x+w,y+h), (125,10,20), 5)
    
    cv2.drawContours(img, [c], -1, (0,255,0), 2)
    cv2.circle(img, (cX,cY), 7, (255,255,255), -1)
    cv2.putText(img, "center", (cX-20,cY-20), cv2.FONT_HERSHEY_COMPLEX,0.5,(255,255,255), 2)

cv2.imshow("Original",img)
cv2.imshow("Gray",img1)
cv2.imshow("thresh",thresh)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#Hand Detection using Contours
import cv2
import numpy as np

img = cv2.imread("hand.jpg")
img = cv2.resize(img, (600,700))
img1 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

blur = cv2.medianBlur(img1,9)
ret,thresh = cv2.threshold(blur, 240, 255, cv2.THRESH_BINARY_INV)

#findcontours
cnts,hier = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#cv2.drawContours(img, cnts, -1, (50,50,150), 2)

#Loop over the contours
for c in cnts:
    epsilon = 0.0001 * cv2.arcLength(c, True)
    data = cv2.approxPolyDP(c, epsilon, True)

    hull = cv2.convexHull(data)

    cv2.drawContours(img, [c], -1, (50,50,150), 2)
    cv2.drawContours(img, [hull], -1, (0,255,0), 2)

#find convexity defect
hull2 = cv2.convexHull(cnts[0],returnPoints=False)
#defect return an array which contains value [start_point, end_point, farthest_point, approximation_point]
defect = cv2.convexityDefects(cnts[0], hull2)

for i in range(defect.shape[0]):
    s,e,f,d = defect[i,0]
    start = tuple(c[s][0])
    end = tuple(c[e][0])
    far = tuple(c[f][0])
    #cv2.line(img,start,end,[255,0,0],2)
    cv2.circle(img,far,5,[0,0,255],-1)

#Extreme Points
#It means topmost, bottommost, rightmost and leftmost points
c_max = max(cnts, key=cv2.contourArea)

#determine the most extreme points along the contour
extLeft = tuple(c_max[c_max[:,:,0].argmin()][0])
extRight = tuple(c_max[c_max[:,:,0].argmax()][0])
extTop = tuple(c_max[c_max[:,:,1].argmin()][0])
extBottom = tuple(c_max[c_max[:,:,1].argmax()][0])

#draw the outline of the object, then draw each of the extreme points,
#where the left-most is red, right-most is green, top-most is blue and bottom-most is teal

cv2.circle(img, extLeft, 8, (255,0,255), -1) #pink
cv2.circle(img, extRight, 8, (0,125,255), -1) #brown
cv2.circle(img, extTop, 8, (255,10,0), -1) #blue
cv2.circle(img, extBottom, 8, (19,152,152), -1) #green

cv2.imshow("Original",img)
cv2.imshow("Gray",img1)
cv2.imshow("Thresh",thresh)

cv2.waitKey(0)
cv2.destroyAllWindows()

#plot in graph
import matplotlib.pyplot as plt
plt.imshow(img[:,:,::-1])
plt.title("Contours and Convex Hull")
plt.axis("off")
# Out:
# (-0.5, 599.5, 699.5, -0.5)

# %%
c_max
# Out:
# array([[[334,  38]],
#
#        [[333,  39]],
#
#        [[331,  39]],
#
#        ...,
#
#        [[348,  39]],
#
#        [[346,  39]],
#
#        [[345,  38]]], dtype=int32)

# %%
c_max[:,:,0]
# Out:
# array([[334],
#        [333],
#        [331],
#        ...,
#        [348],
#        [346],
#        [345]], dtype=int32)

# %%
c_max[:,:,0].argmin()
# Out:
# 338

# %%
c_max[338]
# Out:
# array([ 39, 356], dtype=int32)

# %%
#Object Detection using Contours by webcam

import cv2
import numpy as np

#Read Camera
cap = cv2.VideoCapture(0)
def nothing(x):
    pass

#window name
cv2.namedWindow("Color Adjustments",cv2.WINDOW_NORMAL)
cv2.resizeWindow("Color Adjustments", (300,300))
cv2.createTrackbar("Thresh", "Color Adjustments",0,255,nothing)

#Color Detection Track
cv2.createTrackbar("Lower_H", "Color Adjustments", 0, 255, nothing)
cv2.createTrackbar("Lower_S", "Color Adjustments", 0, 255, nothing)
cv2.createTrackbar("Lower_V", "Color Adjustments", 0, 255, nothing)
cv2.createTrackbar("Upper_H", "Color Adjustments", 255, 255, nothing)
cv2.createTrackbar("Upper_S", "Color Adjustments", 255, 255, nothing)
cv2.createTrackbar("Upper_V", "Color Adjustments", 255, 255, nothing)

while True:
    _, frame = cap.read()
    frame = cv2.resize(frame, (400,400))
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    #detecting hand
    l_h = cv2.getTrackbarPos("Lower_H", "Color Adjustments")
    l_s = cv2.getTrackbarPos("Lower_S", "Color Adjustments")
    l_v = cv2.getTrackbarPos("Lower_V", "Color Adjustments")
    u_h = cv2.getTrackbarPos("Upper_H", "Color Adjustments")
    u_s = cv2.getTrackbarPos("Upper_S", "Color Adjustments")
    u_v = cv2.getTrackbarPos("Upper_V", "Color Adjustments")

    lower_bound = np.array([l_h, l_s, l_v])
    upper_bound = np.array([u_h, u_s, u_v])

    #Creating mask
    mask = cv2.inRange(frame, lower_bound, upper_bound)
    #filter mask with image
    filtr = cv2.bitwise_and(frame, frame, mask=mask)

    mask1 = cv2.bitwise_not(mask)
    m_g = cv2.getTrackbarPos("Thresh", "Color Adjustments")
    ret, thresh = cv2.threshold(mask1,m_g,255,cv2.THRESH_BINARY)
    dilate = cv2.dilate(thresh, (1,1), iterations=6)

    #find contours
    cnts, hier = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

    #cv2.drawContours(frame, cnts, -1, (176,10,15), 4)

    #Loop over the contours
    for c in cnts:
        epsilon = 0.0001 * cv2.arcLength(c, True)
        data = cv2.approxPolyDP(c, epsilon, True)

        hull = cv2.convexHull(data)
        cv2.drawContours(frame, [c], -1, (50,50,150), 2)
        cv2.drawContours(frame, [hull], -1, (0,255,0), 2)

    cv2.imshow("Thresh",thresh)
    cv2.imshow("mask",mask)
    cv2.imshow("filter",filtr)
    cv2.imshow("Result",frame)
    if cv2.waitKey(1) == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()

# %%
#Image Histogram - Find, Plot and Analyze
#It gives us an overall idea about the intensity distribution of an image.
#It distribute data along x and y-axis.
# x-axis contains range of color values
# y-axis contains number of pixels in an image
#With histogram we can extract information about contrast, brightness and intensity.
#Plot histogram using matplotlib

import numpy as np
import cv2
import matplotlib.pyplot as plt

#plotting with calhist method
img = np.zeros((200,200), np.uint8)
cv2.rectangle(img,(0,100),(200,200),(255),-1)
cv2.rectangle(img,(0,50),(50,100),(127),-1)

#It accepts parameter like ([img], [channel],mask,[histsize],range)
hist = cv2.calcHist([img],[0],None,[256],[0,256] )

plt.plot(hist)
plt.show()

cv2.imshow("res",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#Histogram with color image
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread("thor.jpg")
img = cv2.resize(img, (500,650))
b, g, r = cv2.split(img)
cv2.imshow("img",img)
cv2.imshow("b",b)
cv2.imshow("g",g)
cv2.imshow("r",r)

#Plotting different channel with hist
plt.hist(b.ravel(),256,[0,256])
plt.hist(g.ravel(),256,[0,256])
plt.hist(r.ravel(),256,[0,256])
plt.title("Colorful image")
plt.show()


cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#Histogram with gray image
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread("thor.jpg")
img = cv2.resize(img, (500,650))
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
hist = cv2.calcHist([img_gray],[0],None,[255],[0,255])

plt.plot(hist)
plt.title("Gray Image")
plt.show()

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
b.ravel()
# Out:
# array([44, 44, 44, ..., 31, 31, 31], dtype=uint8)

# %%
#Histogram equalization is good when the image is confined to a particular region
#It accept gray scale image
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread("thor.jpg")
img = cv2.resize(img, (500,650))
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

equ = cv2.equalizeHist(img_gray)
res = np.hstack((img_gray,equ)) #Stacking images side by side

cv2.imshow("Res",res)

hist1 = cv2.calcHist([equ],[0],None,[256],[0,256])
plt.plot(hist1)
plt.title("Equalization")
plt.show()

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#CLAHE (Contrast Limited Adaptive Histogram Equialization)
#Create a CLAHE object. (Arguments are optional)
#It is used to enhance image and also handle noise from image region
#gray scale image is required
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread("thor.jpg")
img = cv2.resize(img, (500,650))
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

clahe = cv2.createCLAHE(clipLimit=2, tileGridSize=(8,8))
cl1 = clahe.apply(img_gray)

cv2.imshow("Clahe",cl1)

hist2 = cv2.calcHist([cl1],[0],None,[256],[0,256])

plt.plot(hist2)
plt.title("CLAHE")
plt.show()

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#BackProjection using histogram technique

import cv2
import numpy as np

original_image = cv2.imread("green.jpg")
original_image = cv2.resize(original_image,(600,650))
hsv_original = cv2.cvtColor(original_image,cv2.COLOR_BGR2HSV)

roi = cv2.imread("g.jpg")
hsv_roi = cv2.cvtColor(roi,cv2.COLOR_BGR2HSV)

#Histogram ROI
roi_hist = cv2.calcHist([hsv_roi],[0,1],None,[180,256],[0,180,0,256])
mask = cv2.calcBackProject([hsv_original],[0,1],roi_hist,[0,180,0,256],1)

#Filtering Remove noise
kernal = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(5,5))
mask = cv2.filter2D(mask, -1, kernal)
_,mask = cv2.threshold(mask,200,255,cv2.THRESH_BINARY)

mask = cv2.merge((mask,mask,mask))
result = cv2.bitwise_or(original_image,mask)

cv2.imshow("Original Image",original_image)
cv2.imshow("HSV Original",hsv_original)
cv2.imshow("Mask",mask)
cv2.imshow("Result",result)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#Template Matching
"""
It is a method for searching and finding the location of a template image in a larger image.
OpenCV comes with a function cv2.matchTemplate() for this purpose. It simply slides the template image over the input image
(as in 2D covolution) and compares the template and patch of input image over the template image.
"""
import cv2
import numpy as np
import matplotlib.pyplot as plt

#Target
img = cv2.imread("avengers.jpg")
grey_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

#Load Template
template = cv2.imread("temp.jpg",0)

w,h = template.shape[::-1]

#Template matching
#This function accepts parameter (img, template, method)
res = cv2.matchTemplate(grey_img, template, cv2.TM_CCORR_NORMED)

threshold = 0.99
loc = np.where(res>=threshold) #Finding bright pixel

for i in zip(*loc[::-1]):
    cv2.rectangle(img, i, (i[0]+w, i[1]+h), (0,0,255),2)


img = cv2.resize(img, (800,600))
cv2.imshow("img",img)

res = cv2.resize(res, (800,600))
cv2.imshow("res",res)

cv2.waitKey(0)
cv2.destroyAllWindows()

plt.imshow(img[:,:,::-1])
plt.title("Template matching")
plt.axis("off")
plt.show()

# %%
"""
Hough Transform is a popular technique to detect any shape, 
if you can represent that shape in mathematical form.
It can detect the shape even if it is broken or distorted a little bit.
fuctions : cv2.HoughLines(), cv2.HoughLinesP()
"""

#Steps:
#Convert image into gray
#Detect edges 
#Then apply Hough method

#------cv2.HoughLines()-----

#We represent the shape with the help of lines
#And line are expressed for Hough Transform by --
#Cartesian CS(Coordinate System) ---> y = mx + c and Polar CS ----> xcosθ + ysinθ

import cv2
import numpy as np

img = cv2.imread("chess.jpg")
img = cv2.resize(img, (400,400))
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
edges = cv2.Canny(gray, 20, 250)

#functions accept parameter (img, rho, theta)
lines = cv2.HoughLines(edges, 1, np.pi/180, 200)
#rough value --- distance resolution of pixels
#theta ---- angle resolution
#line threshold
for rho, theta in lines[0]:
    a = np.cos(theta)
    b = np.sin(theta)
    x0 = a * rho
    y0 = b * rho
    x1 = int(x0 + 1000 * (-b))
    y1 = int(y0 + 1000 * (a))
    x2 = int(x0 - 1000 * (-b))
    y2 = int(y0 - 1000 * (a))
    cv2.line(img, (x1, y1), (x2, y2), (0, 0, 255), 2) 

cv2.imshow("edges",edges)
cv2.imshow("lines",img)

cv2.waitKey(0)
cv2.destroyAllWindows()

plt.imshow(img[:,:,::-1])
plt.title("HoughLines")
plt.axis("off")
# Out:
# (-0.5, 399.5, 399.5, -0.5)

# %%
#------cv2.HoughLinesP()-----
#Mostly used than HoughLines()
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread("chess.jpg")
img = cv2.resize(img, (400,400))
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
edges = cv2.Canny(gray, 20, 250)

lines = cv2.HoughLinesP(edges, 1, np.pi/180, 100, minLineLength=8, maxLineGap=100)

for line in lines:
    x1,y1,x2,y2 = line[0]
    cv2.line(img, (x1,y1), (x2,y2), (100,200,125), 2)

cv2.imshow("edges",edges)
cv2.imshow("lines",img)

cv2.waitKey(0)
cv2.destroyAllWindows()

plt.imshow(img[:,:,::-1])
plt.title("HoughLinesP")
plt.axis("off")
# Out:
# (-0.5, 399.5, 399.5, -0.5)

# %%
#Circle detection using OpenCV and HoughCircle
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread("col_balls.jpg")
img2 = img.copy()
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray = cv2.medianBlur(gray, 5)

#parameters-- (img, circle_method, dp, mindist, param1, param2[p1>p2],)
circles = cv2.HoughCircles(gray, cv2.HOUGH_GRADIENT,1,20, param1=50, param2=30, minRadius=0, maxRadius=0)
data = np.uint16(np.around(circles))

for x,y,r in data[0]:
    cv2.circle(img2,(x,y),r,(50,10,50),3)
    cv2.circle(img2,(x,y),2,(0,255,100),-1)

cv2.imshow("result",img2)
cv2.imshow("gray",gray)

cv2.waitKey(0)
cv2.destroyAllWindows()

plt.imshow(img2[:,:,::-1])
plt.title("Hough Circle")
plt.axis("off")
plt.show()

# %%
#Circle detection in webcam using HoughCircle
import cv2
import numpy as np

cap = cv2.VideoCapture(0)

while True:
    _, img = cap.read()
    img2 = img.copy()
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    gray = cv2.medianBlur(gray, 5)

    circles = cv2.HoughCircles(gray,cv2.HOUGH_GRADIENT,1,50,param1=50,param2=30,minRadius=0,maxRadius=0)

    if circles is not None:
        data = np.uint16(np.around(circles))
        for x,y,r in data[0]:
            cv2.circle(img2,(x,y),r,(50,10,50),3)
            cv2.circle(img2,(x,y),2,(0,255,100),-1)

    cv2.imshow("res",img2)

    if cv2.waitKey(1) == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()

# %%
#Grabcut Algorithm
#With the help of this algorithm we easily cut off any foreground object from image or video.
#It works like a rectangular portion mark ont the image and the area outside the rectangle is treated as an extra part
#so this algorithm remove it completely
#Gaussian mixture model help to achieve the target

import numpy as np
import cv2
import matplotlib.pyplot as plt

img = cv2.imread("car.jpg")
img = cv2.resize(img, (800,800))
mask = np.zeros(img.shape[:2],np.uint8)

bgdModel = np.zeros((1,65),np.float64)*255
fgdModel = np.zeros((1,65),np.float64)*255

#parameter (img, mask, rect, bgmodel, fgmodel, iter, method)
rect = (134,150,660,730) #foreground
cv2.grabCut(img,mask,rect,bgdModel,fgdModel,5,cv2.GC_INIT_WITH_RECT)

mask2 = np.where((mask==2)|(mask==0),0,1).astype("uint8")
img = img *mask2[:,:,np.newaxis]

cv2.imshow("res",img)
#cv2.imshow("mask",mask2*255)

cv2.waitKey(0)
cv2.destroyAllWindows()

plt.imshow(img[:,:,::-1])
plt.title("Grabcut")
plt.axis("off")
plt.show()

# %%
#Feature Detection and Description

#Corner Detection
"""
For understanding this we recall jigsaw puzzle game where we combine multiple small pieces in correct order
by identifying its corners, shape and pattern

On the basis of all these we detect corners in images with so many approach
"""
#Harris Corner Detection
"""
OpenCV has the function cv2.cornerHarris() for this purpose. Its arguments are:

img - Input image, it should be grayscale and float32 type.
blockSize - It is the size of neighbourhood considered for corner detection.
ksize - Aperture parameter of Sobel derivative used.
k - Harris detector free parameter in the equation.
"""

import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread("shapes.png")

#gray Conversion
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray = np.float32(gray)

#detect corner
res = cv2.cornerHarris(gray,5,3,0.04)

img[res > 0.01 * res.max()] = [0,0,255] #marked color


cv2.imshow("img",img)

cv2.waitKey(0)
cv2.destroyAllWindows()

plt.imshow(img[:,:,::-1])
plt.title("Harris Corner Detection")
plt.axis("off")
plt.show()

# %%
#Corner Detector -- Shi-Tomasi Corner Detector
#We will see the function : cv2.goodFeaturesToTrack().
#Shi-Tomasi approach is more effective as compared with Harris Corner Detection

#In this we limit the numbers of corners and corner quality.
#It is more user-friendly

import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread("shapes.png")
#image must be in gray
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

#parameter (img, no. of corner, quality_Level, min_distance between corner)
corners = cv2.goodFeaturesToTrack(gray, 30, 0.01, 20)
corners = np.int64(corners)

for i in corners:
    x,y = i.ravel()
    cv2.circle(img,(x,y),3,255,-1)

cv2.imshow("res",img)

cv2.waitKey(0)
cv2.destroyAllWindows()

plt.imshow(img[:,:,::-1])
plt.title("Shi-Tomasi Corner Detection")
plt.axis("off")
plt.show()

# %%
#Video Background Removal
#Background Subtraction is a way to access the foreground objects.
#Technically, you need to extract the moving foreground from static background.
#There are multiple approaches for background subtraction

import cv2
import numpy as np
cap = cv2.VideoCapture("test2.mp4")

algo1 = cv2.createBackgroundSubtractorMOG2()
algo2 = cv2.createBackgroundSubtractorKNN(detectShadows=True)

while True:
    ret, frame = cap.read()
    frame = cv2.resize(frame,(600,400))
    res1 = algo1.apply(frame)
    res2 = algo2.apply(frame)

    cv2.imshow("original",frame)
    cv2.imshow("res1",res1)
    cv2.imshow("res2",res2)

    x = cv2.bitwise_and(frame,frame,mask=res2)
    cv2.imshow("x",x)
    
    k = cv2.waitKey(60)
    if k == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()

# %%
#Object tracking using meanshift algorithm
#The idea behind this algo is to move small window to get the high
# density pixels same as histogram backprojection

#Steps to use this algo ---
#First setup target and find its histogram for backproject the target.
#Also set one initial location.
#setup the termination criteria.

import cv2
import numpy as np
cap = cv2.VideoCapture("test2.mp4")

#take first frame of the video
ret,frame = cap.read()

#setup initial location of window
x, y, width, height = 580, 30, 80, 150
track = (x,y,width,height)

#setup the ROI for tracking
roi = frame[y:y+height, x:x+width]
hsv_roi = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

mask = cv2.inRange(hsv_roi, np.array((0.,60.,32.)), np.array((180.,255.,255)))
roi_hist = cv2.calcHist([hsv_roi],[0],mask,[180],[0,180])
cv2.normalize(roi_hist,roi_hist,0,255, cv2.NORM_MINMAX)

#Setup the termination criteria, either 10 iteration or move by atleast 1 point
termtn = (cv2.TERM_CRITERIA_EPS | cv2.TERM_CRITERIA_COUNT,10, 1)


while True:
    ret, frame = cap.read()
    if ret == True:
        hsv = cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)
        dst = cv2.calcBackProject([hsv],[0],roi_hist,[0,180],1)

        #apply meanshift to get the new location
        ret, track = cv2.meanShift(dst,track,termtn)

        #draw it on image
        x,y,w,h = track
        final = cv2.rectangle(frame,(x,y),(x+w,y+h),(0,0,255),3)
        
        frame = cv2.resize(final,(600,600))
        cv2.imshow("original",frame)
        k = cv2.waitKey(30) & 0xFF
        if k == 27:
            break
    else:
        break

cv2.destroyAllWindows()

# %%
#Object Tracking using CAMshift (Continuously Adaptive Meanshift) algorithm
import cv2
import numpy as np
cap = cv2.VideoCapture("test2.mp4")

#take first frame of the video
ret,frame = cap.read()

#setup initial location of window
x, y, width, height = 580, 30, 80, 150
track = (x,y,width,height)

#setup the ROI for tracking
roi = frame[y:y+height, x:x+width]
hsv_roi = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

mask = cv2.inRange(hsv_roi, np.array((0.,60.,32.)), np.array((180.,255.,255)))
roi_hist = cv2.calcHist([hsv_roi],[0],mask,[180],[0,180])
cv2.normalize(roi_hist,roi_hist,0,255, cv2.NORM_MINMAX)

#Setup the termination criteria, either 10 iteration or move by atleast 1 point
termtn = (cv2.TERM_CRITERIA_EPS | cv2.TERM_CRITERIA_COUNT,10, 1)


while True:
    ret, frame = cap.read()
    if ret == True:
        hsv = cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)
        dst = cv2.calcBackProject([hsv],[0],roi_hist,[0,180],1)

        #apply CAMshift to get the new location
        ret, track = cv2.CamShift(dst,track,termtn)

        #draw it on image
        #x,y,w,h = track
        #final = cv2.rectangle(frame,(x,y),(x+w,y+h),(0,0,255),3)

        #Try to draw rotating rectangle
        pts = cv2.boxPoints(ret)
        pts = np.int64(pts)
        final = cv2.polylines(frame,[pts],True,(255,0,0),2)
        
        frame = cv2.resize(final,(600,600))
        cv2.imshow("original",frame)
        k = cv2.waitKey(30) & 0xFF
        if k == 27:
            break
    else:
        break

cv2.destroyAllWindows()

# %%
#Optical Flow-- Lucas Kanade method
#Optical flow is the pattern of apparent motion of image objects
#between two consecutive frames caused by the movement of object or camera.

#Optical flow works on several assumptions:

#The pixel intensities of an object do not change between consecutive frame.
#Neighbouring pixels have similar motion.

import cv2
import numpy as np

cap = cv2.VideoCapture("test2.mp4")

#params for shi-tomasi corner detection
feature_params = dict( maxCorners = 100,
                       qualityLevel = 0.3,
                       minDistance = 7,
                       blockSize = 7 )

#Parameters for Lucas Kanade Optical flow
lk_params = dict( winSize = (15,15),
                  maxLevel = 2,
                  criteria = (cv2.TERM_CRITERIA_EPS | cv2.TERM_CRITERIA_COUNT, 10, 0.03))

#Create some random colors
color = np.random.randint(0,255,(100,3))

#Take first frame and find corners in it.
ret, old_frame = cap.read()
old_gray = cv2.cvtColor(old_frame,cv2.COLOR_BGR2GRAY)
p0 = cv2.goodFeaturesToTrack(old_gray,mask=None, **feature_params)

#Create a mask for drawing purposes
mask = np.zeros_like(old_frame)

while True:
    ret, frame = cap.read()

    frame_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    #Calculate optical flow
    p1, st, err = cv2.calcOpticalFlowPyrLK(old_gray, frame_gray, p0, None, **lk_params)

    #Select good points
    good_new = p1[st==1]
    good_old = p0[st==1]

    #draw the tracks
    for i,(new,old) in enumerate(zip(good_new,good_old)):
        a,b = np.uint32(np.around(new.ravel()))
        c,d = np.uint32(np.around(old.ravel()))
        mask = cv2.line(mask,(a,b),(c,d),color[i].tolist(),2)
        frame = cv2.circle(frame, (a,b),5,color[i].tolist(),-1)
        
    img = cv2.add(frame,mask)
    frame = cv2.resize(img,(700,600))
    
    cv2.imshow("frame",frame)
    
    k = cv2.waitKey(30) & 0xFF
    if k == 27:
        break

    #Now update the previous frames and previous points
    old_gray = frame_gray.copy()
    p0 = good_new.reshape(-1,1,2)

cv2.destroyAllWindows()

# %%
#Optical Flow -- Gunner Farneback's algorithm
import cv2
import numpy as np
cap = cv2.VideoCapture(0)

ret, frame1 = cap.read()
prvs = cv2.cvtColor(frame1, cv2.COLOR_BGR2GRAY)
hsv = np.zeros_like(frame1)
hsv[..., 1] = 255

while(1):
    ret, frame2 = cap.read()
    next = cv2.cvtColor(frame2,cv2.COLOR_BGR2GRAY)

    flow = cv2.calcOpticalFlowFarneback(prvs, next, None, 0.5, 3, 15, 3,5,1.2,0)

    mag, ang = cv2.cartToPolar(flow[...,0], flow[...,1])
    hsv[...,0] = ang*180/np.pi/2
    hsv[...,2] = cv2.normalize(mag, None, 0, 255, cv2.NORM_MINMAX)
    rgb = cv2.cvtColor(hsv, cv2.COLOR_HSV2BGR)

    img1 = cv2.add(frame2,rgb)
    img1 = cv2.resize(img1,(700,430))

    cv2.imshow("frame2",img1)

    k = cv2.waitKey(30) & 0xFF
    if k == 27:
        break

    prvs = next

cv2.destroyAllWindows()

# %%
#Face and Eye detection in image

#Face detection using harcascade file
import cv2
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread("a.jpg")
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) #Convert into gray
face = cv2.CascadeClassifier("haarcascade_frontalface_default.xml") #For detecting face
eye = cv2.CascadeClassifier("haarcascade_eye.xml") #for detecting eye


#parameters(img, scale_factor[reduce image size], min_neighbour)
faces = face.detectMultiScale(gray,4,4) #for faces

for (x,y,w,h) in faces:
    image = cv2.rectangle(image,(x,y),(x+w,y+h),(127,0,205),3)

    #Now detect eyes
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = image[y:y+h, x:x+w]
    eyes = eye.detectMultiScale(roi_gray, 1.2, 1)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(255,0,0),2)

image = cv2.resize(image, (800,600))

cv2.imshow("Face Detected",image)

cv2.waitKey(0)
cv2.destroyAllWindows()

plt.imshow(image[:,:,::-1])
plt.title("Face Detection")
plt.axis("off")
plt.show()

# %%
#Face and eye detection using webcam
import cv2
import numpy as np

face = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
eye = cv2.CascadeClassifier("haarcascade_eye.xml")

def detector(img):
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face.detectMultiScale(gray,1.3,5)
    for (x,y,w,h) in faces:
        cv2.rectangle(img, (x,y),(x+w,y+h),(127,0,125),3)
        
        roi_gray = gray[y:y+h,x:x+w]

        roi_color = img[y:y+h, x:x+w]

        eyes = eye.detectMultiScale(roi_gray,1.3,3)
        for (ex,ey,ew,eh) in eyes:
            cv2.circle(roi_color,(ex+27,ey+27),20,(255,255,0),2)
        
    return img

cap = cv2.VideoCapture(0)
while True:
    ret, frame = cap.read()
    frame = cv2.flip(frame,2)

    cv2.imshow("face detect",detector(frame))
    if cv2.waitKey(1) == 13: #Press Enter to terminate
        break

cap.release()
cv2.destroyAllWindows()

# %%
#Cat face detection using harcascade
import cv2
import numpy as np
import matplotlib.pyplot as plt

face = cv2.CascadeClassifier("haarcascade_frontalcatface.xml")

image = cv2.imread("dogcat2.jpeg")
gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

faces = face.detectMultiScale(gray,1.1,1)

for (x,y,w,h) in faces:
    cv2.rectangle(image,(x,y),(x+w,y+h),(255,0,0),2)

image = cv2.resize(image,(800,700))
cv2.imshow("Face Detected",image)

cv2.waitKey(0)
cv2.destroyAllWindows()

plt.imshow(image[:,:,::-1])
plt.title("Cat detection")
plt.axis("off")
plt.show()

# %% [markdown]
# END
